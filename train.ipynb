# %%
# %load_ext autoreload
# %autoreload 2

import toml

import torch as th

from mmidas.utils.tools import get_paths
from train import treemap, load_config, load_augmenter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cfg1 = get_paths("config.toml", "mouse_smartseq", True)
cfg2 = load_config("config.toml")
# Out:
# loading mouse_smartseq paths
# config:
# {'SEA-AD': {'anndata_file': '',
#             'aug_model': '',
#             'data_path': 'data/human_AD/',
#             'htree_file': 'tree_human_MTG_2023.csv',
#             'saving_path': 'results/human_AD/',
#             'trained_model': ''},
#  'mouse_ctx_10x': {'anndata_file': '',
#                    'aug_model': '',
#                    'data_path': 'data/mouse_ctx_10x/',
#                    'htree_file': 'tree_Mouse_cortex_2020.csv',
#                    'saving_path': 'results/mouse_ctx_10x/',
#                    'trained_model': ''},
#  'mouse_smartseq': {'anndata_file': 'Mouse_ALM-VISp_cpm.h5ad',
#                     'aug_model': PosixPath('smartseq_augmenter/trained_augmenter_bs_1000_dn_50_dz_10_l1_1.0_l2_0.5_l3_0.1_l4_0.50'),
#                     'data_path': PosixPath('data'),
#                     'htree_file': 'tree_Mouse_ALM-VISp_2018.csv',
#                     'ref_gene_file': 'genes_SS_ALM-VISp.csv',
# ...

# %%
cfg1
# Out:
# {'project': {'name': 'mmidas',
#   'description': 'Couple Mixture VAE models for single cell data',
#   'version': '0.1.0',
#   'requires-python': '>= 3.8',
#   'authors': [{'name': 'Yeganeh Marghi',
#     'email': 'yeganeh.marghi@alleninstitute.org'},
#    {'name': 'Rohan Gala', 'email': 'rohang@alleninstitute.org'}],
#   'readme': 'README.md'},
#  'paths': {'main_dir': PosixPath('/Users/hilalmufti/programs/distributed-vae')},
#  'mouse_smartseq': {'anndata_file': 'Mouse_ALM-VISp_cpm.h5ad',
#   'htree_file': 'tree_Mouse_ALM-VISp_2018.csv',
#   'ref_gene_file': 'genes_SS_ALM-VISp.csv',
#   'data_path': PosixPath('data'),
#   'saving_path': PosixPath('mmidas-results'),
#   'aug_model': PosixPath('smartseq_augmenter/trained_augmenter_bs_1000_dn_50_dz_10_l1_1.0_l2_0.5_l3_0.1_l4_0.50'),
#   'trained_model': 'K92_S2_AUGTrue_LR0.001_A3_B5000_E500000_Ep0_RUN1'},
#  'mouse_ctx_10x': {'anndata_file': '',
#   'htree_file': 'tree_Mouse_cortex_2020.csv',
#   'data_path': 'data/mouse_ctx_10x/',
# ...

# %%
cfg2
# Out:
# {'project': {'name': 'mmidas',
#   'description': 'Couple Mixture VAE models for single cell data',
#   'version': '0.1.0',
#   'requires-python': '>= 3.8',
#   'authors': [{'name': 'Yeganeh Marghi',
#     'email': 'yeganeh.marghi@alleninstitute.org'},
#    {'name': 'Rohan Gala', 'email': 'rohang@alleninstitute.org'}],
#   'readme': 'README.md'},
#  'paths': {'main_dir': PosixPath('/Users/hilalmufti/programs/distributed-vae')},
#  'mouse_smartseq': {'anndata_file': PosixPath('Mouse_ALM-VISp_cpm.h5ad'),
#   'htree_file': PosixPath('tree_Mouse_ALM-VISp_2018.csv'),
#   'ref_gene_file': PosixPath('genes_SS_ALM-VISp.csv'),
#   'data_path': PosixPath('data'),
#   'saving_path': PosixPath('mmidas-results'),
#   'aug_model': PosixPath('smartseq_augmenter/trained_augmenter_bs_1000_dn_50_dz_10_l1_1.0_l2_0.5_l3_0.1_l4_0.50'),
#   'trained_model': PosixPath('K92_S2_AUGTrue_LR0.001_A3_B5000_E500000_Ep0_RUN1')},
#  'mouse_ctx_10x': {'anndata_file': PosixPath('.'),
# ...

# %%
load_augmenter()
# Out:
# ...
# /Users/hilalmufti/programs/distributed-vae/train.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = th.load(file, map_location="cpu")
# Augmenter_smartseq(
# ...
